# %% [markdown]
# <a href="https://colab.research.google.com/github/JunYoung07/Python_AI_Project/blob/main/18_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 너비 우선 탐색(BFS, Breadth-First Search)

# %% [markdown]
# ### 1-1. BFS란?
# * 대표적인 그래프 탐색 알고리즘
# * 정점들과 같은 레벨에 있는 노드(형제 노드)들을 먼저 탐색하는 방식
# * 한 단계씩 내려가면서 해당 노드와 같은 레벨에 있는 노드들을 먼저 순회함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 방문했던 장소를 저장할 **큐**(선입선출)
# * 방문이 필요한 장소를 저장할 **큐**

# %%
# 그래프(인접행렬) 정의하기
graph = dict()

# 인접 행렬
graph['A'] = ['B', 'C']
graph['B'] = ['A', 'D']
graph['C'] = ['A', 'G', 'H', 'I']
graph['D'] = ['B', 'E', 'F']
graph['E'] = ['D']
graph['F'] = ['D']
graph['G'] = ['C']
graph['H'] = ['C']
graph['I'] = ['C', 'J']
graph['J'] = ['I']

# %%
graph
# Out:
# {'A': ['B', 'C'],
#  'B': ['A', 'D'],
#  'C': ['A', 'G', 'H', 'I'],
#  'D': ['B', 'E', 'F'],
#  'E': ['D'],
#  'F': ['D'],
#  'G': ['C'],
#  'H': ['C'],
#  'I': ['C', 'J'],
#  'J': ['I']}

# %% [markdown]
# # 2. BFS 알고리즘 구현

# %% [markdown]
# * **큐** 자료구조 활용
# * `need_visit`zb, `visited`큐 생성

# %%
# 리스트로 큐 구현 data.pop(0)
# data.extend([4, 5]) 기존 리스트에 새로운 리스트 연결

# BFS 구현
def bfs(graph, start_node):
    visited, need_visit = [], []

    need_visit.append(start_node)

    while need_visit:
        node = need_visit.pop(0)
        if node not in visited:
            visited.append(node)
            need_visit.extend(graph[node])
    
    return visited

# %%
bfs(graph, 'A')
# Out:
# ['A', 'B', 'C', 'D', 'G', 'H', 'I', 'E', 'F', 'J']
